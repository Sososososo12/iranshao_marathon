# %%
import xlrd
import xlwt
import pandas as pd
import csv
import numpy as np

# %%
nums=[]
wb = xlrd.open_workbook(filename=r'./persons_article_num.xls')
sheet1 = wb.sheet_by_index(0)
# 读取excel中sheet1里第二列的数据
article_sites = sheet1.col_values(0)
for i in article_sites:
    nums.append(i)

# %%
data=pd.DataFrame(pd.read_excel('./persons_article_num.xls'))
data.drop_duplicates('persons_id','first',inplace=True)
data
# Out:
#     persons_article_num                      persons_id
# 0                     0                      4815da377e
# 1                     0                      96288955ad
# 2                     1                      183509bae4
# 3                     0                    isabel_zhang
# 4                     2                 mai-gong-xia-mi
# 5                     0                    wu-xi-ai-pao
# 6                     0                      irs_ae10e2
# 7                     0                      414cb225fe
# 10                    0                      86e4080033
# 11                    0                      53db24f661
# 12                    0                           zwjnt
# 13                    0         qing-dao-wang-xuan-feng
# 15                    0                      920f7d66af
# 16                    0                      fea7988424
# 17                    0                      86b9195b18
# 18                    0                      7fe68f65e5
# ...

# %%
truenumber=(data['persons_article_num']>0)
data[truenumber]
# Out:
#     persons_article_num                      persons_id
# 2                     1                      183509bae4
# 4                     2                 mai-gong-xia-mi
# 21                    2                wu-di-da-jin-jin
# 23                    7                      irs_c25d19
# 24                    1                      irs_65eca8
# 57                    1                      e846a5fedd
# 59                    1                     xiao-dong-4
# 60                    1                       lu-dai-ri
# 64                   17                           ka-ka
# 67                    2                      6e76fc6376
# 68                    1       jue-shi-2-zui-mei-lu-zhou
# 87                    2                      b5d7237146
# 88                    1                   huo-zhe-alive
# 96                    7                        dian-man
# 98                    2  wang-shu-dong-fa-yan-ren-sheng
