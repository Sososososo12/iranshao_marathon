# %%
import xlrd
import xlwt
import pandas as pd

# %%
filepath='./hangzhou_comment_sen.xls'

# %%
data=pd.DataFrame(pd.read_excel(filepath))

# %%
data
# Out:
#                                               paragragh  \
# 0               二度杭马，天气还算给力，由于之前一周青马摔趴，青紫未褪养腿一周，5公里后...
# 1                                   换掉智美以后终于可以参赛了
# 2               第一次全马，后段坡比较多，累成狗，路边的志愿者小姐姐还是很体贴漂亮的。。...
# 3               为梦想而奋斗加油'跑步带给我的快乐，希望在2019年跑出自已最好成绩出来...
# 4                        杭🐎2018跑过、各方面都不错、期待2019杭🐎
# 5               今年杭马比去年杭马有所提升，但是刚刚起步没多久西湖边上就开始堵起来，根本...
# 6                                    挺不错的比赛，值得推荐。
# 7               优点 : 赛道风景好；补给充足；杭马印奖牌设计独特。缺点 : 起点志愿者...
# 8               跑了18年杭半马，开始没中签，单位是赞助商后来要了直通名额，11月份气温...
# 9                                     赛事很棒，明年争取继续
# 10                                       个人感觉 一般般
# 11                                        个人感觉一般般
# 12                给美女做私兔的，谁知人家一起跑就去追310兔子，跑爆了！汗颜！
# 13                            跑得爽，体会到什么叫腿如铅注，无能为力
# 14                                      跑过风景，跑过你。
# 15              家门口的比赛，从开始跑步已连续四年参赛，口碑和赛事水平也在逐年提升，跑过...
# 16              杭马进步很大，特别是安全岛，落实很到位，协调市民出行和赛道安全。线路不够...
# ...

# %%
# 获取索引的数量长度、步进值
data.index
# Out:
# RangeIndex(start=0, stop=1198, step=1)

# %%
# 获取列的性质
data.columns
# Out:
# Index(['paragragh', 'person_url'], dtype='object')

# %%
data['cut_sentence']=None

# %%
data
# Out:
#                                               paragragh  \
# 0               二度杭马，天气还算给力，由于之前一周青马摔趴，青紫未褪养腿一周，5公里后...
# 1                                   换掉智美以后终于可以参赛了
# 2               第一次全马，后段坡比较多，累成狗，路边的志愿者小姐姐还是很体贴漂亮的。。...
# 3               为梦想而奋斗加油'跑步带给我的快乐，希望在2019年跑出自已最好成绩出来...
# 4                        杭🐎2018跑过、各方面都不错、期待2019杭🐎
# 5               今年杭马比去年杭马有所提升，但是刚刚起步没多久西湖边上就开始堵起来，根本...
# 6                                    挺不错的比赛，值得推荐。
# 7               优点 : 赛道风景好；补给充足；杭马印奖牌设计独特。缺点 : 起点志愿者...
# 8               跑了18年杭半马，开始没中签，单位是赞助商后来要了直通名额，11月份气温...
# 9                                     赛事很棒，明年争取继续
# 10                                       个人感觉 一般般
# 11                                        个人感觉一般般
# 12                给美女做私兔的，谁知人家一起跑就去追310兔子，跑爆了！汗颜！
# 13                            跑得爽，体会到什么叫腿如铅注，无能为力
# 14                                      跑过风景，跑过你。
# 15              家门口的比赛，从开始跑步已连续四年参赛，口碑和赛事水平也在逐年提升，跑过...
# 16              杭马进步很大，特别是安全岛，落实很到位，协调市民出行和赛道安全。线路不够...
# ...
